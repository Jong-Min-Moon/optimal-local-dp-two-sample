# %%
import sys
sys.path.insert(0, '/mnt/nas/users/mjm/LDPUts')

from discretizer import discretizer
from client import client
import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
import matplotlib.pyplot as plt
from server import server_ell2, server_multinomial_genrr, server_multinomial_bitflip
from data_generator import data_generator
from discretizer import discretizer
import time
import numpy as np
from scipy.stats import chi2
from utils import chi_sq_dist

# %%
n_test = 1000
n_permutation = 299
significance_level = 0.05
alphabet_size = 500

###################
sample_size = 500
###################

data_gen = data_generator(device)

p = torch.ones(alphabet_size)
p = p.divide(p.sum())

plt.plot(p)

p_value_array_priv_01 = np.zeros([n_test, 3])
p_value_array_priv_05 = np.zeros([n_test, 3])
p_value_array_priv_10 = np.zeros([n_test, 3])
p_value_array_priv_20 = np.zeros([n_test, 3])

# %% [markdown]
# ## privacy level = 0.1

# %%
privacy_level = 0.1

LDPclient = client(device, privacy_level)
server_elltwo = server_ell2(device, privacy_level)
server_genrr = server_multinomial_genrr(device, privacy_level)
server_bitflip = server_multinomial_bitflip(device, privacy_level)

t = time.time()
for i in range(n_test):
    print(f"{i+1}th test")
    torch.manual_seed(i)
    data_y = data_gen.generate_multinomial_data(p, sample_size)
    data_z = data_gen.generate_multinomial_data(p, sample_size)
    
    LDPclient.load_data_multinomial(data_y, data_z, alphabet_size)
    data_list_lapu_y, data_list_lapu_z = LDPclient.release_lapu()
    data_list_genrr_y, data_list_genrr_z = LDPclient.release_genrr()
    data_list_bitflip_y, data_list_bitflip_z = LDPclient.release_bitflip()
    
    server_elltwo.load_private_data_multinomial(data_list_lapu_y, data_list_lapu_z, alphabet_size)
    p_value_array_priv_01[i,0] = server_elltwo.release_p_value_permutation(n_permutation)
 
    server_genrr.load_private_data_multinomial(data_list_genrr_y, data_list_genrr_z, alphabet_size)
    p_value_array_priv_01[i,1] = server_genrr.release_p_value()
     
    server_bitflip.load_private_data_multinomial(data_list_bitflip_y, data_list_bitflip_z, alphabet_size)
    p_value_array_priv_01[i,2] = server_bitflip.release_p_value()
elapsed = time.time() - t
print(elapsed)
print(
   # f"small chi-square distance\n"+
        f"privacy level = {privacy_level}"
)


with open('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_500_alpha_01_type_1_unif.npy', 'wb') as f:
    np.save(f, p_value_array_priv_01)
# Out:
# 1th test
# 2th test
# 3th test
# 4th test
# 5th test
# 6th test
# 7th test
# 8th test
# 9th test
# 10th test
# 11th test
# 12th test
# 13th test
# 14th test
# 15th test
# 16th test
# 17th test
# 18th test
# 19th test
# 20th test
# 21th test
# 22th test
# 23th test
# 24th test
# 25th test
# 26th test
# 27th test
# 28th test
# 29th test
# 30th test
# 31th test
# 32th test
# 33th test
# 34th test
# 35th test
# 36th test
# 37th test
# 38th test
# 39th test
# 40th test
# 41th test
# 42th test
# 43th test
# 44th test
# 45th test
# 46th test
# 47th test
# 48th test
# 49th test
# 50th test
# 51th test
# 52th test
# 53th test
# 54th test
# 55th test
# 56th test
# 57th test
# 58th test
# 59th test
# 60th test
# 61th test
# 62th test
# 63th test
# 64th test
# 65th test
# 66th test
# 67th test
# 68th test
# 69th test
# 70th test
# 71th test
# 72th test
# 73th test
# 74th test
# 75th test
# 76th test
# 77th test
# 78th test
# 79th test
# 80th test
# 81th test
# 82th test
# 83th test
# 84th test
# 85th test
# 86th test
# 87th test
# 88th test
# 89th test
# 90th test
# 91th test
# 92th test
# 93th test
# 94th test
# 95th test
# 96th test
# 97th test
# 98th test
# 99th test
# 100th test
# 101th test
# 102th test
# 103th test
# 104th test
# 105th test
# 106th test
# 107th test
# 108th test
# 109th test
# 110th test
# 111th test
# 112th test
# 113th test
# 114th test
# 115th test
# 116th test
# 117th test
# 118th test
# 119th test
# 120th test
# 121th test
# 122th test
# 123th test
# 124th test
# 125th test
# 126th test
# 127th test
# 128th test
# 129th test
# 130th test
# 131th test
# 132th test
# 133th test
# 134th test
# 135th test
# 136th test
# 137th test
# 138th test
# 139th test
# 140th test
# 141th test
# 142th test
# 143th test
# 144th test
# 145th test
# 146th test
# 147th test
# 148th test
# 149th test
# 150th test
# 151th test
# 152th test
# 153th test
# 154th test
# 155th test
# 156th test
# 157th test
# 158th test
# 159th test
# 160th test
# 161th test
# 162th test
# 163th test
# 164th test
# 165th test
# 166th test
# 167th test
# 168th test
# 169th test
# 170th test
# 171th test
# 172th test
# 173th test
# 174th test
# 175th test
# 176th test
# 177th test
# 178th test
# 179th test
# 180th test
# 181th test
# 182th test
# 183th test
# 184th test
# 185th test
# 186th test
# 187th test
# 188th test
# 189th test
# 190th test
# 191th test
# 192th test
# 193th test
# 194th test
# 195th test
# 196th test
# 197th test
# 198th test
# 199th test
# 200th test
# 201th test
# 202th test
# 203th test
# 204th test
# 205th test
# 206th test
# 207th test
# 208th test
# 209th test
# 210th test
# 211th test
# 212th test
# 213th test
# 214th test
# 215th test
# 216th test
# 217th test
# 218th test
# 219th test
# 220th test
# 221th test
# 222th test
# 223th test
# 224th test
# 225th test
# 226th test
# 227th test
# 228th test
# 229th test
# 230th test
# 231th test
# 232th test
# 233th test
# 234th test
# 235th test
# 236th test
# 237th test
# 238th test
# 239th test
# 240th test
# 241th test
# 242th test
# 243th test
# 244th test
# 245th test
# 246th test
# 247th test
# 248th test
# 249th test
# 250th test
# 251th test
# 252th test
# 253th test
# 254th test
# 255th test
# 256th test
# 257th test
# 258th test
# 259th test
# 260th test
# 261th test
# 262th test
# 263th test
# 264th test
# 265th test
# 266th test
# 267th test
# 268th test
# 269th test
# 270th test
# 271th test
# 272th test
# 273th test
# 274th test
# 275th test
# 276th test
# 277th test
# 278th test
# 279th test
# 280th test
# 281th test
# 282th test
# 283th test
# 284th test
# 285th test
# 286th test
# 287th test
# 288th test
# 289th test
# 290th test
# 291th test
# 292th test
# 293th test
# 294th test
# 295th test
# 296th test
# 297th test
# 298th test
# 299th test
# 300th test
# 301th test
# 302th test
# 303th test
# 304th test
# 305th test
# 306th test
# 307th test
# 308th test
# 309th test
# 310th test
# 311th test
# 312th test
# 313th test
# 314th test
# 315th test
# 316th test
# 317th test
# 318th test
# 319th test
# 320th test
# 321th test
# 322th test
# 323th test
# 324th test
# 325th test
# 326th test
# 327th test
# 328th test
# 329th test
# 330th test
# 331th test
# 332th test
# 333th test
# 334th test
# 335th test
# 336th test
# 337th test
# 338th test
# 339th test
# 340th test
# 341th test
# 342th test
# 343th test
# 344th test
# 345th test
# 346th test
# 347th test
# 348th test
# 349th test
# 350th test
# 351th test
# 352th test
# 353th test
# 354th test
# 355th test
# 356th test
# 357th test
# 358th test
# 359th test
# 360th test
# 361th test
# 362th test
# 363th test
# 364th test
# 365th test
# 366th test
# 367th test
# 368th test
# 369th test
# 370th test
# 371th test
# 372th test
# 373th test
# 374th test
# 375th test
# 376th test
# 377th test
# 378th test
# 379th test
# 380th test
# 381th test
# 382th test
# 383th test
# 384th test
# 385th test
# 386th test
# 387th test
# 388th test
# 389th test
# 390th test
# 391th test
# 392th test
# 393th test
# 394th test
# 395th test
# 396th test
# 397th test
# 398th test
# 399th test
# 400th test
# 401th test
# 402th test
# 403th test
# 404th test
# 405th test
# 406th test
# 407th test
# 408th test
# 409th test
# 410th test
# 411th test
# 412th test
# 413th test
# 414th test
# 415th test
# 416th test
# 417th test
# 418th test
# 419th test
# 420th test
# 421th test
# 422th test
# 423th test
# 424th test
# 425th test
# 426th test
# 427th test
# 428th test
# 429th test
# 430th test
# 431th test
# 432th test
# 433th test
# 434th test
# 435th test
# 436th test
# 437th test
# 438th test
# 439th test
# 440th test
# 441th test
# 442th test
# 443th test
# 444th test
# 445th test
# 446th test
# 447th test
# 448th test
# 449th test
# 450th test
# 451th test
# 452th test
# 453th test
# 454th test
# 455th test
# 456th test
# 457th test
# 458th test
# 459th test
# 460th test
# 461th test
# 462th test
# 463th test
# 464th test
# 465th test
# 466th test
# 467th test
# 468th test
# 469th test
# 470th test
# 471th test
# 472th test
# 473th test
# 474th test
# 475th test
# 476th test
# 477th test
# 478th test
# 479th test
# 480th test
# 481th test
# 482th test
# 483th test
# 484th test
# 485th test
# 486th test
# 487th test
# 488th test
# 489th test
# 490th test
# 491th test
# 492th test
# 493th test
# 494th test
# 495th test
# 496th test
# 497th test
# 498th test
# 499th test
# 500th test
# 501th test
# 502th test
# 503th test
# 504th test
# 505th test
# 506th test
# 507th test
# 508th test
# 509th test
# 510th test
# 511th test
# 512th test
# 513th test
# 514th test
# 515th test
# 516th test
# 517th test
# 518th test
# 519th test
# 520th test
# 521th test
# 522th test
# 523th test
# 524th test
# 525th test
# 526th test
# 527th test
# 528th test
# 529th test
# 530th test
# 531th test
# 532th test
# 533th test
# 534th test
# 535th test
# 536th test
# 537th test
# 538th test
# 539th test
# 540th test
# 541th test
# 542th test
# 543th test
# 544th test
# 545th test
# 546th test
# 547th test
# 548th test
# 549th test
# 550th test
# 551th test
# 552th test
# 553th test
# 554th test
# 555th test
# 556th test
# 557th test
# 558th test
# 559th test
# 560th test
# 561th test
# 562th test
# 563th test
# 564th test
# 565th test
# 566th test
# 567th test
# 568th test
# 569th test
# 570th test
# 571th test
# 572th test
# 573th test
# 574th test
# 575th test
# 576th test
# 577th test
# 578th test
# 579th test
# 580th test
# 581th test
# 582th test
# 583th test
# 584th test
# 585th test
# 586th test
# 587th test
# 588th test
# 589th test
# 590th test
# 591th test
# 592th test
# 593th test
# 594th test
# 595th test
# 596th test
# 597th test
# 598th test
# 599th test
# 600th test
# 601th test
# 602th test
# 603th test
# 604th test
# 605th test
# 606th test
# 607th test
# 608th test
# 609th test
# 610th test
# 611th test
# 612th test
# 613th test
# 614th test
# 615th test
# 616th test
# 617th test
# 618th test
# 619th test
# 620th test
# 621th test
# 622th test
# 623th test
# 624th test
# 625th test
# 626th test
# 627th test
# 628th test
# 629th test
# 630th test
# 631th test
# 632th test
# 633th test
# 634th test
# 635th test
# 636th test
# 637th test
# 638th test
# 639th test
# 640th test
# 641th test
# 642th test
# 643th test
# 644th test
# 645th test
# 646th test
# 647th test
# 648th test
# 649th test
# 650th test
# 651th test
# 652th test
# 653th test
# 654th test
# 655th test
# 656th test
# 657th test
# 658th test
# 659th test
# 660th test
# 661th test
# 662th test
# 663th test
# 664th test
# 665th test
# 666th test
# 667th test
# 668th test
# 669th test
# 670th test
# 671th test
# 672th test
# 673th test
# 674th test
# 675th test
# 676th test
# 677th test
# 678th test
# 679th test
# 680th test
# 681th test
# 682th test
# 683th test
# 684th test
# 685th test
# 686th test
# 687th test
# 688th test
# 689th test
# 690th test
# 691th test
# 692th test
# 693th test
# 694th test
# 695th test
# 696th test
# 697th test
# 698th test
# 699th test
# 700th test
# 701th test
# 702th test
# 703th test
# 704th test
# 705th test
# 706th test
# 707th test
# 708th test
# 709th test
# 710th test
# 711th test
# 712th test
# 713th test
# 714th test
# 715th test
# 716th test
# 717th test
# 718th test
# 719th test
# 720th test
# 721th test
# 722th test
# 723th test
# 724th test
# 725th test
# 726th test
# 727th test
# 728th test
# 729th test
# 730th test
# 731th test
# 732th test
# 733th test
# 734th test
# 735th test
# 736th test
# 737th test
# 738th test
# 739th test
# 740th test
# 741th test
# 742th test
# 743th test
# 744th test
# 745th test
# 746th test
# 747th test
# 748th test
# 749th test
# 750th test
# 751th test
# 752th test
# 753th test
# 754th test
# 755th test
# 756th test
# 757th test
# 758th test
# 759th test
# 760th test
# 761th test
# 762th test
# 763th test
# 764th test
# 765th test
# 766th test
# 767th test
# 768th test
# 769th test
# 770th test
# 771th test
# 772th test
# 773th test
# 774th test
# 775th test
# 776th test
# 777th test
# 778th test
# 779th test
# 780th test
# 781th test
# 782th test
# 783th test
# 784th test
# 785th test
# 786th test
# 787th test
# 788th test
# 789th test
# 790th test
# 791th test
# 792th test
# 793th test
# 794th test
# 795th test
# 796th test
# 797th test
# 798th test
# 799th test
# 800th test
# 801th test
# 802th test
# 803th test
# 804th test
# 805th test
# 806th test
# 807th test
# 808th test
# 809th test
# 810th test
# 811th test
# 812th test
# 813th test
# 814th test
# 815th test
# 816th test
# 817th test
# 818th test
# 819th test
# 820th test
# 821th test
# 822th test
# 823th test
# 824th test
# 825th test
# 826th test
# 827th test
# 828th test
# 829th test
# 830th test
# 831th test
# 832th test
# 833th test
# 834th test
# 835th test
# 836th test
# 837th test
# 838th test
# 839th test
# 840th test
# 841th test
# 842th test
# 843th test
# 844th test
# 845th test
# 846th test
# 847th test
# 848th test
# 849th test
# 850th test
# 851th test
# 852th test
# 853th test
# 854th test
# 855th test
# 856th test
# 857th test
# 858th test
# 859th test
# 860th test
# 861th test
# 862th test
# 863th test
# 864th test
# 865th test
# 866th test
# 867th test
# 868th test
# 869th test
# 870th test
# 871th test
# 872th test
# 873th test
# 874th test
# 875th test
# 876th test
# 877th test
# 878th test
# 879th test
# 880th test
# 881th test
# 882th test
# 883th test
# 884th test
# 885th test
# 886th test
# 887th test
# 888th test
# 889th test
# 890th test
# 891th test
# 892th test
# 893th test
# 894th test
# 895th test
# 896th test
# 897th test
# 898th test
# 899th test
# 900th test
# 901th test
# 902th test
# 903th test
# 904th test
# 905th test
# 906th test
# 907th test
# 908th test
# 909th test
# 910th test
# 911th test
# 912th test
# 913th test
# 914th test
# 915th test
# 916th test
# 917th test
# 918th test
# 919th test
# 920th test
# 921th test
# 922th test
# 923th test
# 924th test
# 925th test
# 926th test
# 927th test
# 928th test
# 929th test
# 930th test
# 931th test
# 932th test
# 933th test
# 934th test
# 935th test
# 936th test
# 937th test
# 938th test
# 939th test
# 940th test
# 941th test
# 942th test
# 943th test
# 944th test
# 945th test
# 946th test
# 947th test
# 948th test
# 949th test
# 950th test
# 951th test
# 952th test
# 953th test
# 954th test
# 955th test
# 956th test
# 957th test
# 958th test
# 959th test
# 960th test
# 961th test
# 962th test
# 963th test
# 964th test
# 965th test
# 966th test
# 967th test
# 968th test
# 969th test
# 970th test
# 971th test
# 972th test
# 973th test
# 974th test
# 975th test
# 976th test
# 977th test
# 978th test
# 979th test
# 980th test
# 981th test
# 982th test
# 983th test
# 984th test
# 985th test
# 986th test
# 987th test
# 988th test
# 989th test
# 990th test
# 991th test
# 992th test
# 993th test
# 994th test
# 995th test
# 996th test
# 997th test
# 998th test
# 999th test
# 1000th test
# 585.6078889369965
# privacy level = 0.1

# %%
type_1_nominal = np.linspace(0,1,100)
type_1_real_ell2_01 = np.zeros(100)
type_1_real_genrr_01 = np.zeros(100)
type_1_real_bitflip_01 = np.zeros(100)

for i, level in enumerate(type_1_nominal):
    type_1_real_ell2_01[i] = sum( p_value_array_priv_01[:,0]<level)/n_test
    type_1_real_genrr_01[i] = sum( p_value_array_priv_01[:,1]<level)/n_test
    type_1_real_bitflip_01[i] = sum( p_value_array_priv_01[:,2]<level)/n_test
    

plt.plot(type_1_nominal, type_1_nominal)
plt.plot(type_1_nominal, type_1_real_ell2_01)
plt.plot(type_1_nominal, type_1_real_genrr_01)
plt.plot(type_1_nominal, type_1_real_bitflip_01)

# %% [markdown]
# ## privacy level = 0.5

# %%
privacy_level = 0.5

LDPclient = client(device, privacy_level)
server_elltwo = server_ell2(device, privacy_level)
server_genrr = server_multinomial_genrr(device, privacy_level)
server_bitflip = server_multinomial_bitflip(device, privacy_level)

t = time.time()
for i in range(n_test):
    print(f"{i+1}th test")
    torch.manual_seed(i)
    data_y = data_gen.generate_multinomial_data(p, sample_size)
    data_z = data_gen.generate_multinomial_data(p, sample_size)
    
    LDPclient.load_data_multinomial(data_y, data_z, alphabet_size)
    data_list_lapu_y, data_list_lapu_z = LDPclient.release_lapu()
    data_list_genrr_y, data_list_genrr_z = LDPclient.release_genrr()
    data_list_bitflip_y, data_list_bitflip_z = LDPclient.release_bitflip()
    
    server_elltwo.load_private_data_multinomial(data_list_lapu_y, data_list_lapu_z, alphabet_size)
    p_value_array_priv_05[i,0] = server_elltwo.release_p_value_permutation(n_permutation)
 
    server_genrr.load_private_data_multinomial(data_list_genrr_y, data_list_genrr_z, alphabet_size)
    p_value_array_priv_05[i,1] = server_genrr.release_p_value()
     
    server_bitflip.load_private_data_multinomial(data_list_bitflip_y, data_list_bitflip_z, alphabet_size)
    p_value_array_priv_05[i,2] = server_bitflip.release_p_value()
elapsed = time.time() - t
print(elapsed)
print(
   # f"small chi-square distance\n"+
        f"privacy level = {privacy_level}"
)


with open('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_500_alpha_05_type_1_unif', 'wb') as f:
    np.save(f, p_value_array_priv_05)

# %% [markdown]
# ## privacy level = 1.0

# %%
privacy_level = 1.0

LDPclient = client(device, privacy_level)
server_elltwo = server_ell2(device, privacy_level)
server_genrr = server_multinomial_genrr(device, privacy_level)
server_bitflip = server_multinomial_bitflip(device, privacy_level)

t = time.time()
for i in range(n_test):
    print(f"{i+1}th test")
    torch.manual_seed(i)
    data_y = data_gen.generate_multinomial_data(p, sample_size)
    data_z = data_gen.generate_multinomial_data(p, sample_size)
    
    LDPclient.load_data_multinomial(data_y, data_z, alphabet_size)
    data_list_lapu_y, data_list_lapu_z = LDPclient.release_lapu()
    data_list_genrr_y, data_list_genrr_z = LDPclient.release_genrr()
    data_list_bitflip_y, data_list_bitflip_z = LDPclient.release_bitflip()
    
    server_elltwo.load_private_data_multinomial(data_list_lapu_y, data_list_lapu_z, alphabet_size)
    p_value_array_priv_10[i,0] = server_elltwo.release_p_value_permutation(n_permutation)
 
    server_genrr.load_private_data_multinomial(data_list_genrr_y, data_list_genrr_z, alphabet_size)
    p_value_array_priv_10[i,1] = server_genrr.release_p_value()
     
    server_bitflip.load_private_data_multinomial(data_list_bitflip_y, data_list_bitflip_z, alphabet_size)
    p_value_array_priv_10[i,2] = server_bitflip.release_p_value()
elapsed = time.time() - t
print(elapsed)
print(
   # f"small chi-square distance\n"+
        f"privacy level = {privacy_level}"
)


with open('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_500_alpha_10_type_1_unif', 'wb') as f:
    np.save(f, p_value_array_priv_10)

# %% [markdown]
# ## privacy level = 2.0

# %%
privacy_level = 2.0

LDPclient = client(device, privacy_level)
server_elltwo = server_ell2(device, privacy_level)
server_genrr = server_multinomial_genrr(device, privacy_level)
server_bitflip = server_multinomial_bitflip(device, privacy_level)

t = time.time()
for i in range(n_test):
    print(f"{i+1}th test")
    torch.manual_seed(i)
    data_y = data_gen.generate_multinomial_data(p, sample_size)
    data_z = data_gen.generate_multinomial_data(p, sample_size)
    
    LDPclient.load_data_multinomial(data_y, data_z, alphabet_size)
    data_list_lapu_y, data_list_lapu_z = LDPclient.release_lapu()
    data_list_genrr_y, data_list_genrr_z = LDPclient.release_genrr()
    data_list_bitflip_y, data_list_bitflip_z = LDPclient.release_bitflip()
    
    server_elltwo.load_private_data_multinomial(data_list_lapu_y, data_list_lapu_z, alphabet_size)
    p_value_array_priv_20[i,0] = server_elltwo.release_p_value_permutation(n_permutation)
 
    server_genrr.load_private_data_multinomial(data_list_genrr_y, data_list_genrr_z, alphabet_size)
    p_value_array_priv_20[i,1] = server_genrr.release_p_value()
     
    server_bitflip.load_private_data_multinomial(data_list_bitflip_y, data_list_bitflip_z, alphabet_size)
    p_value_array_priv_20[i,2] = server_bitflip.release_p_value()
elapsed = time.time() - t
print(elapsed)
print(
   # f"small chi-square distance\n"+
        f"privacy level = {privacy_level}"
)


with open('/mnt/nas/users/mjm/LDPUts/simul/type_1/hi_dim/unif/k_500_n_500_alpha_10_type_20_unif', 'wb') as f:
    np.save(f, p_value_array_priv_20)
