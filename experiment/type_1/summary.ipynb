# %%
import matplotlib.pyplot as plt
import os
import numpy as np
print(os.getcwd())
# Out:
# /Users/jmmoon/Documents/GitHub/LDPUts/simul/type_1

# %%
k_500_n_500_powerlaw = np.load('./powerlaw/alpha_01/k_500_n_500_alpha_01_type_1_unif.npy')
k_500_n_1000_unif = np.load('./unif/alpha_01/k_500_n_1000_alpha_01_type_1_unif.npy')
k_500_n_1500_powerlaw = np.load('./powerlaw/alpha_01/k_500_n_1500_alpha_01_type_1_powerlaw.npy')

table_powerlaw_500 = np.zeros([100,4])
table_powerlaw_1000 = np.zeros([100,4])
table_powerlaw_1500 = np.zeros([100,4])

table_powerlaw_500[:,0] = np.linspace(0,1,100)
table_powerlaw_1000[:,0] = np.linspace(0,1,100)
table_powerlaw_1500[:,0] = np.linspace(0,1,100)

for i, level in enumerate(type_1_nominal):
    table_powerlaw_500[i,1] = ( k_500_n_500_powerlaw[:,0]<level).mean()
    table_powerlaw_500[i,2] = ( k_500_n_500_powerlaw[:,1]<level).mean()
    table_powerlaw_500[i,3] = ( k_500_n_500_powerlaw[:,2]<level).mean()
    
    table_powerlaw_1000[i,1] = ( k_500_n_1000_powerlaw[:,0]<level).mean()
    table_powerlaw_1000[i,2] = ( k_500_n_1000_powerlaw[:,1]<level).mean()
    table_powerlaw_1000[i,3] = ( k_500_n_1000_powerlaw[:,2]<level).mean()
    
    table_powerlaw_1500[i,1] = ( k_500_n_1500_powerlaw[:,0]<level).mean()
    table_powerlaw_1500[i,2] = ( k_500_n_1500_powerlaw[:,1]<level).mean()
    table_powerlaw_1500[i,3] = ( k_500_n_1500_powerlaw[:,2]<level).mean()
np.savetxt('type1_powerlaw_priv01_n500.csv', table_powerlaw_500, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")
np.savetxt('type1_powerlaw_priv01_n1000.csv', table_powerlaw_1000, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")
np.savetxt('type1_powerlaw_priv01_n1500.csv', table_powerlaw_1500, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")

# %% [markdown]
# ## Power law, privacy level = 0.1

# %%
#plot

plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,0])
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,1])
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,0])
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,2])
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,0])
plt.plot(table_powerlaw_500[:,0], table_powerlaw_500[:,3])
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')

# %%
plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1500)
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1500)
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(type_1_nominal, type_1_nominal)
#lt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n500)
plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1000)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1500)
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')

# %%
plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_ell2_n1500)
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_genrr_n1500)
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(type_1_nominal, type_1_nominal)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n500)
#plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1000)
plt.plot(type_1_nominal, type_1_real_powerlaw_bitflip_n1500)
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')

# %%
k_500_n_500_unif = np.load('./unif/k_500_n_500_alpha_01_type_1_unif.npy')
k_500_n_1000_unif = np.load('./unif/k_500_n_1000_alpha_01_type_1_unif.npy')
k_500_n_1500_unif = np.load('./unif/k_500_n_1500_alpha_01_type_1_unif.npy')



table_unif_500 = np.zeros([100,4])
table_unif_1000 = np.zeros([100,4])
table_unif_1500 = np.zeros([100,4])

table_unif_500[:,0] = np.linspace(0,1,100)
table_unif_1000[:,0] = np.linspace(0,1,100)
table_unif_1500[:,0] = np.linspace(0,1,100)

for i, level in enumerate(type_1_nominal):
    table_unif_500[i,1] = ( k_500_n_500_unif[:,0]<level).mean()
    table_unif_500[i,2] = ( k_500_n_1000_unif[:,1]<level).mean()
    table_unif_500[i,3] = ( k_500_n_500_unif[:,2]<level).mean()
    
    table_unif_1000[i,1] = ( k_500_n_1000_unif[:,0]<level).mean()
    table_unif_1000[i,2] = ( k_500_n_1000_unif[:,1]<level).mean()
    table_unif_1000[i,3] = ( k_500_n_1000_unif[:,2]<level).mean()
    
    table_unif_1500[i,1] = ( k_500_n_1500_unif[:,0]<level).mean()
    table_unif_1500[i,2] = ( k_500_n_1500_unif[:,1]<level).mean()
    table_unif_1500[i,3] = ( k_500_n_1500_unif[:,2]<level).mean()
np.savetxt('type1_unif_priv01_n500.csv', table_unif_500, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")
np.savetxt('type1_unif_priv01_n1000.csv', table_unif_1000, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")
np.savetxt('type1_unif_priv01_n1500.csv', table_unif_1500, delimiter = ',', header = "nominal, lapu, genrr, bitflip", comments = "")

# %%
#plot

plt.figure(figsize=(30, 10))
plt.subplot(1,3,1)
plt.plot(table_unif_500[:,0], table_unif_500[:,0])
plt.plot(table_unif_500[:,0], table_unif_500[:,1])
plt.title("lapu+ ell2")

plt.subplot(1,3,2)
plt.plot(table_unif_500[:,0], table_unif_500[:,0])
plt.plot(table_unif_500[:,0], table_unif_500[:,2])
plt.title("genrr+ chi-sq")

plt.subplot(1,3,3)
plt.plot(table_unif_500[:,0], table_unif_500[:,0])
plt.plot(table_unif_500[:,0], table_unif_500[:,3])
plt.title("bitflip  + chi-sq-proj")
# Out:
# Text(0.5, 1.0, 'bitflip  + chi-sq-proj')
